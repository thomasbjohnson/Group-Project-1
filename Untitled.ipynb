# %%
# %matplotlib notebook

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
artist_file = "Data/top10s.csv"

# %%
# Read our Data file with the pandas library
artist_file_df = pd.read_csv(artist_file, encoding="cp1252")
# Show just the header
artist_file_df.head()
# Out:
#    Unnamed: 0                 title      artist        top genre  year  bpm  \
# 0           1      Hey, Soul Sister       Train       neo mellow  2010   97
# 1           2  Love The Way You Lie      Eminem  detroit hip hop  2010   87
# 2           3               TiK ToK       Kesha        dance pop  2010  120
# 3           4           Bad Romance   Lady Gaga        dance pop  2010  119
# 4           5  Just the Way You Are  Bruno Mars              pop  2010  109
#
#    nrgy  dnce  dB  live  val  dur  acous  spch  pop
# 0    89    67  -4     8   80  217     19     4   83
# 1    93    75  -5    52   64  263     24    23   82
# 2    84    76  -3    29   71  200     10    14   80
# 3    92    70  -4     8   71  295      0     4   79
# 4    84    64  -5     9   43  221      2     4   78

# %%
# Show just the header
artist_file_df.head()
# Out:
#    Unnamed: 0                 title      artist        top genre  year  bpm  \
# 0           1      Hey, Soul Sister       Train       neo mellow  2010   97
# 1           2  Love The Way You Lie      Eminem  detroit hip hop  2010   87
# 2           3               TiK ToK       Kesha        dance pop  2010  120
# 3           4           Bad Romance   Lady Gaga        dance pop  2010  119
# 4           5  Just the Way You Are  Bruno Mars              pop  2010  109
#
#    nrgy  dnce  dB  live  val  dur  acous  spch  pop
# 0    89    67  -4     8   80  217     19     4   83
# 1    93    75  -5    52   64  263     24    23   82
# 2    84    76  -3    29   71  200     10    14   80
# 3    92    70  -4     8   71  295      0     4   79
# 4    84    64  -5     9   43  221      2     4   78

# %%
# Show mulitple specific columns--note the extra brackets
artist_file_df[["artist", "year"]].head()
# Out:
#        artist  year
# 0       Train  2010
# 1      Eminem  2010
# 2       Kesha  2010
# 3   Lady Gaga  2010
# 4  Bruno Mars  2010

# %%
artist_count=artist_file_df["artist"].value_counts()
#add a condition if the name of the artist is >= 5 then plot on the graph

best_artist = artist_count.where(artist_count>=5).dropna()

print(best_artist)
# Out:
# Katy Perry             17.0
# Justin Bieber          16.0
# Maroon 5               15.0
# Rihanna                15.0
# Lady Gaga              14.0
# Bruno Mars             13.0
# Shawn Mendes           11.0
# The Chainsmokers       11.0
# Pitbull                11.0
# Ed Sheeran             11.0
# Calvin Harris          10.0
# Adele                  10.0
# Jennifer Lopez         10.0
# Ariana Grande           9.0
# OneRepublic             9.0
# Kesha                   9.0
# David Guetta            9.0
# Britney Spears          9.0
# Justin Timberlake       9.0
# Beyoncé                 8.0
# Demi Lovato             8.0
# Selena Gomez            8.0
# Taylor Swift            8.0
# One Direction           7.0
# DNCE                    7.0
# Sia                     6.0
# Alicia Keys             6.0
# Nicki Minaj             6.0
# P!nk                    6.0
# Zedd                    6.0
# Meghan Trainor          6.0
# Christina Aguilera      6.0
# Ellie Goulding          5.0
# ...

# %%
# Create a bar chart based off of the group series from before
count_chart = best_artist.plot(kind='bar')



# Set the xlabel and ylabel using class methods
count_chart.set_xlabel("Artist Name")
count_chart.set_ylabel("Number of Times on Billboard")


plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
artist_cnt= artist_file_df[["artist"]].value_counts()
print(artist_cnt)
# Out:
# artist
# Katy Perry                  17
# Justin Bieber               16
# Maroon 5                    15
# Rihanna                     15
# Lady Gaga                   14
#                             ..
# Lilly Wood and The Prick     1
# Lily Allen                   1
# Lorde                        1
# Luis Fonsi                   1
# 3OH!3                        1
# Length: 184, dtype: int64

# %%
# Set x axis and tick locations
x_axis = np.arange(len(artist_file_df))
tick_locations = [value+0.4 for value in x_axis]

# %%
# Create a list indicating where to write x labels and set figure size to adjust for space
plt.figure(figsize=(20,3))
plt.bar(x_axis, artist_cnt, color='b', alpha=0.5, align="edge")
plt.xticks(tick_locations, artist_file_df["artist"], rotation="vertical")
# Out:
# <img src="data:image/png;base64,..." width="2000">
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-72cd088f8bad> in <module>
#       1 # Create a list indicating where to write x labels and set figure size to adjust for space
#       2 plt.figure(figsize=(20,3))
# ----> 3 plt.bar(x_axis, artist_cnt, color='b', alpha=0.5, align="edge")
#       4 plt.xticks(tick_locations, artist_file_df["artist"], rotation="vertical")
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2487     return gca().bar(
#    2488         x, height, width=width, bottom=bottom, align=align,
# -> 2489         **({"data": data} if data is not None else {}), **kwargs)
#    2490
#    2491
#
# ...

# %%
# Set x and y limits
plt.xlim(-0.25, len(x_axis))
plt.ylim(0, max(artist_cnt)+4)

# %%
# Give our chart some labels and a tile
plt.title("Popularity of Artist from 2010-2019")
plt.xlabel("Artist")
plt.ylabel("Number of times charted on Billboard")

# %%
# Save our graph and show the grap
plt.tight_layout()
#plt.savefig("../")
plt.show()

# %%
# Collect the user's input to search through our data frame
artist_name = input("What artist would you like to search for?")

# %%
# Create a group based on the values in the 'artist' column
#artist_group = artist_file_df.groupby('artist')

# Count how many times each artist appears in our group
#count_artist = artist_group['artist'].count()
#court_artist1 =# Create a new dataframe for those wrestlers who have wrestled at least 100 matches,
# have at least one win in 2013,
# and have at least one win in 2016


#count_artist

# %%
# Create a series that looks for a artist by name and then traces their charts from 2010 to 2019
#charts_over_time =

# %%
# Create a list of the years that we will use as our x axis
#years = [2010,2011,2012,2013,2014,2015,2016,2017,2018,2019]

# Plot our line that will be used to track a wrestler's wins over the years
#plt.plot(years, charts_over_time, color="green", label="Wins")


# Place a legend on the chart in what matplotlib believes to be the "best" location
#plt.legend(loc="best")

#plt.title(wrestler_name + "'s Recent Career")
#plt.xlabel("Years")
#plt.xticks(np.arange(min(years), max(years)+1, 1.0))
#plt.ylabel("Number of Chart")

# Print our chart to the screen
#plt.show()
