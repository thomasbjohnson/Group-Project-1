# %%
# %matplotlib notebook

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
artist_file = "top10s.csv"

# %%
# Read our Data file with the pandas library
artist_file_df = pd.read_csv(artist_file, encoding="cp1252")
# Show just the header
artist_file_df.head()
# Out:
#    Unnamed: 0                 title      artist        top genre  year  bpm  \
# 0           1      Hey, Soul Sister       Train       neo mellow  2010   97
# 1           2  Love The Way You Lie      Eminem  detroit hip hop  2010   87
# 2           3               TiK ToK       Kesha        dance pop  2010  120
# 3           4           Bad Romance   Lady Gaga        dance pop  2010  119
# 4           5  Just the Way You Are  Bruno Mars              pop  2010  109
#
#    nrgy  dnce  dB  live  val  dur  acous  spch  pop
# 0    89    67  -4     8   80  217     19     4   83
# 1    93    75  -5    52   64  263     24    23   82
# 2    84    76  -3    29   71  200     10    14   80
# 3    92    70  -4     8   71  295      0     4   79
# 4    84    64  -5     9   43  221      2     4   78

# %%
# Show just the header
#artist_file_df.head()

# %%
# Show mulitple specific columns--note the extra brackets
#artist_file_df[["artist", "year"]].head()

# %%
artist_count=artist_file_df["artist"].value_counts()
#add a condition if the name of the artist is >= 5 then plot on the graph

#artist_count_filter=pd.Series(artist_file_df['artist'>=5]).value_counts()
artist_count_filtered=artist_count.where(artist_count>=5).dropna()
print(artist_count_filtered)
# Out:
# Katy Perry             17.0
# Justin Bieber          16.0
# Rihanna                15.0
# Maroon 5               15.0
# Lady Gaga              14.0
# Bruno Mars             13.0
# Shawn Mendes           11.0
# Pitbull                11.0
# The Chainsmokers       11.0
# Ed Sheeran             11.0
# Adele                  10.0
# Calvin Harris          10.0
# Jennifer Lopez         10.0
# Justin Timberlake       9.0
# Ariana Grande           9.0
# David Guetta            9.0
# Kesha                   9.0
# Britney Spears          9.0
# OneRepublic             9.0
# Demi Lovato             8.0
# Beyoncé                 8.0
# Taylor Swift            8.0
# Selena Gomez            8.0
# DNCE                    7.0
# One Direction           7.0
# Alicia Keys             6.0
# Nicki Minaj             6.0
# Zedd                    6.0
# Christina Aguilera      6.0
# Sia                     6.0
# Meghan Trainor          6.0
# P!nk                    6.0
# Birdy                   5.0
# ZAYN                    5.0
# Miley Cyrus             5.0
# Ellie Goulding          5.0
# Kelly Clarkson          5.0
# The Weeknd              5.0
# The Black Eyed Peas     5.0
# Little Mix              5.0
# Enrique Iglesias        5.0
# Carly Rae Jepsen        5.0
# Name: artist, dtype: float64

# %%
# Create a bar chart based off of the group series from before
count_chart = artist_count_filtered.plot(kind='bar')

# Set the xlabel and ylabel using class methods
count_chart.set_xlabel("Artist Name")
count_chart.set_ylabel("Number of Times on Billboard")
plt.title("Popularity of Artist from 2010-2019")


plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
artist_cnt= artist_file_df[["artist"]].value_counts()
print(artist_cnt)
# Out:
# artist
# Katy Perry                  17
# Justin Bieber               16
# Maroon 5                    15
# Rihanna                     15
# Lady Gaga                   14
#                             ..
# Lilly Wood and The Prick     1
# Lily Allen                   1
# Lorde                        1
# Luis Fonsi                   1
# 3OH!3                        1
# Length: 184, dtype: int64

# %%
# Set x and y limits
#plt.xlim(-0.25, len(x_axis))
plt.ylim(0, max(artist_count_filtered)+4)
# Out:
# (0.0, 21.0)

# %%
# Save our graph and show the grap
plt.tight_layout()
#plt.savefig("../")
plt.show()
